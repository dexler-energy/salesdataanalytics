# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import rcParams

rcParams['figure.figsize'] = 15, 15

import seaborn as sns

# %%
xl = pd.read_excel('DEXLER BD CUSTOMER TRACKER DATA.xlsx', sheet_name = 'Sheet1')

# %%
xl
# Out:
#      S NO       Date                               Customer  \
# 0       1 2014-08-14                           AARESS STEEL
# 1       2 2015-01-20                Abhinav AlloysPvt. Ltd.
# 2       3 2015-01-19                Accurate Steel Forgings
# 3       4 2015-01-19                          Acme Forgings
# 4       5 2014-12-22                     Acme pharma, baddi
# 5       6 2014-12-22               Aditus Laboratories Ltd.
# 6       7 2015-01-16                       Advance Forgings
# 7       8 2015-03-31                 Aerocans India Pvt Ltd
# 8       9 2015-01-20                  Afeco Heating Systems
# 9      10 2014-08-26                              AG Rubber
# 10     11 2014-11-24                   Agarvanshi Aluminium
# 11     12 2015-01-20          Ahmedabad Engineers Pvt. Ltd.
# 12     13 2015-01-07                  Akin Laboratories Ltd
# 13     14 2014-08-21                          AKP Ferrocast
# 14     15 2014-12-09                         AKS Automation
# ...

# %%
xl.drop(['S NO', 'Customer', 'Description', 'Customer Email-Id', 'Remarks', 'Customer Contact'],axis = 1, inplace = True)
xl.columns = ['Date','Industry','Fuel_Used','a','b','c','EA', 'Status', 'Priority', 'Dexler Contact', 'Customer Address', 'State','d','Department','Designation']
xl.drop(['a','b','c','d'], axis = 1, inplace = True)
xl.Fuel_Used.fillna('Unknown', inplace = True)
xl = xl[pd.notnull(xl['State'])]

# %%
#plt.figure(figsize = (15,15))
chart = sns.countplot(x= 'State', data = xl, hue = 'Status')
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45, horizontalalignment = 'right')
# Out:
# [Text(0, 0, 'Karnataka'),
#  Text(0, 0, 'Maharashtra'),
#  Text(0, 0, 'Tamil Nadu'),
#  Text(0, 0, 'Punjab'),
#  Text(0, 0, 'Himachal Pradesh'),
#  Text(0, 0, 'Haryana'),
#  Text(0, 0, 'Telangana'),
#  Text(0, 0, 'Gujarat'),
#  Text(0, 0, 'West Bengal'),
#  Text(0, 0, 'Uttar Pradesh'),
#  Text(0, 0, 'madhya pradesh'),
#  Text(0, 0, 'Goa'),
#  Text(0, 0, 'Madhya Pradesh'),
#  Text(0, 0, 'Uttrakhand'),
#  Text(0, 0, 'Andhra Pradesh'),
#  Text(0, 0, 'Andhra pradesh'),
#  Text(0, 0, 'Kerala'),
#  Text(0, 0, 'Uttar pradesh'),
#  Text(0, 0, 'Rajasthan'),
#  Text(0, 0, 'Dadra & Nagar Haveli'),
#  Text(0, 0, 'Pondicherry'),
#  Text(0, 0, 'Jharkhand'),
#  Text(0, 0, 'Delhi'),
#  Text(0, 0, 'New Delhi'),
#  Text(0, 0, 'Madhya pradesh')]

# %%
#plt.figure(figsize = (15,15))
chart = sns.countplot(x= 'State', data = xl)
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45, horizontalalignment = 'right')
# Out:
# [Text(0, 0, 'Karnataka'),
#  Text(0, 0, 'Maharashtra'),
#  Text(0, 0, 'Tamil Nadu'),
#  Text(0, 0, 'Punjab'),
#  Text(0, 0, 'Himachal Pradesh'),
#  Text(0, 0, 'Haryana'),
#  Text(0, 0, 'Telangana'),
#  Text(0, 0, 'Gujarat'),
#  Text(0, 0, 'West Bengal'),
#  Text(0, 0, 'Uttar Pradesh'),
#  Text(0, 0, 'madhya pradesh'),
#  Text(0, 0, 'Goa'),
#  Text(0, 0, 'Madhya Pradesh'),
#  Text(0, 0, 'Uttrakhand'),
#  Text(0, 0, 'Andhra Pradesh'),
#  Text(0, 0, 'Andhra pradesh'),
#  Text(0, 0, 'Kerala'),
#  Text(0, 0, 'Uttar pradesh'),
#  Text(0, 0, 'Rajasthan'),
#  Text(0, 0, 'Dadra & Nagar Haveli'),
#  Text(0, 0, 'Pondicherry'),
#  Text(0, 0, 'Jharkhand'),
#  Text(0, 0, 'Delhi'),
#  Text(0, 0, 'New Delhi'),
#  Text(0, 0, 'Madhya pradesh')]

# %%
chart = sns.countplot(x= 'State', data = xl.loc[xl['Status'] == 'Disqualified'])
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45, horizontalalignment = 'right')
# Out:
# [Text(0, 0, 'Karnataka'),
#  Text(0, 0, 'Maharashtra'),
#  Text(0, 0, 'Tamil Nadu'),
#  Text(0, 0, 'Punjab'),
#  Text(0, 0, 'Himachal Pradesh'),
#  Text(0, 0, 'Haryana'),
#  Text(0, 0, 'Gujarat'),
#  Text(0, 0, 'Telangana'),
#  Text(0, 0, 'Goa'),
#  Text(0, 0, 'Uttrakhand'),
#  Text(0, 0, 'Kerala'),
#  Text(0, 0, 'West Bengal'),
#  Text(0, 0, 'Rajasthan'),
#  Text(0, 0, 'Pondicherry'),
#  Text(0, 0, 'Jharkhand'),
#  Text(0, 0, 'Delhi'),
#  Text(0, 0, 'Andhra Pradesh'),
#  Text(0, 0, 'Uttar Pradesh'),
#  Text(0, 0, 'Madhya Pradesh'),
#  Text(0, 0, 'Uttar pradesh')]

# %%
chart = sns.countplot(x= 'State', data = xl.loc[xl['Status'] == 'Prospect'])
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45, horizontalalignment = 'right')
# Out:
# [Text(0, 0, 'Karnataka'),
#  Text(0, 0, 'Tamil Nadu'),
#  Text(0, 0, 'Maharashtra'),
#  Text(0, 0, 'Madhya Pradesh'),
#  Text(0, 0, 'Rajasthan'),
#  Text(0, 0, 'Madhya pradesh')]

# %%
#plt.figure(figsize = (15,15))
chart = sns.countplot(x= 'Dexler Contact', data = xl, hue = 'Status')
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45, horizontalalignment = 'right')
# Out:
# [Text(0, 0, 'Mayukh'),
#  Text(0, 0, 'Himanshu'),
#  Text(0, 0, 'Anuj'),
#  Text(0, 0, 'Karan/Piyush'),
#  Text(0, 0, 'Raunak'),
#  Text(0, 0, 'Karan'),
#  Text(0, 0, 'Ikram'),
#  Text(0, 0, 'Mukund'),
#  Text(0, 0, 'Piyush'),
#  Text(0, 0, 'Gurpreet'),
#  Text(0, 0, 'Dinesh'),
#  Text(0, 0, 'Anuj/kumarswamy/ikram/piyush'),
#  Text(0, 0, 'Diwakar')]

# %%
def explode(df, lst_cols, fill_value='', preserve_index=False):
    # make sure `lst_cols` is list-alike
    if (lst_cols is not None
        and len(lst_cols) > 0
        and not isinstance(lst_cols, (list, tuple, np.ndarray, pd.Series))):
        lst_cols = [lst_cols]
    # all columns except `lst_cols`
    idx_cols = df.columns.difference(lst_cols)
    # calculate lengths of lists
    lens = df[lst_cols[0]].str.len()
    # preserve original index values    
    idx = np.repeat(df.index.values, lens)
    # create "exploded" DF
    res = (pd.DataFrame({
                col:np.repeat(df[col].values, lens)
                for col in idx_cols},
                index=idx)
             .assign(**{col:np.concatenate(df.loc[lens>0, col].values)
                            for col in lst_cols}))
    # append those rows that have empty lists
    if (lens == 0).any():
        # at least one list in cells is empty
        res = (res.append(df.loc[lens==0, idx_cols], sort=False)
                  .fillna(fill_value))
    # revert the original index order
    res = res.sort_index()
    # reset index if requested
    if not preserve_index:        
        res = res.reset_index(drop=True)
    return res


xl1 = explode(xl.assign(Fuel_Used=xl.Fuel_Used.str.split(',')), 'Fuel_Used')

# %%
chart = sns.countplot(x= "Fuel_Used", data= xl1)
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45, horizontalalignment = 'right')
# Out:
# [Text(0, 0, 'Unknown'),
#  Text(0, 0, 'FO'),
#  Text(0, 0, 'LPG'),
#  Text(0, 0, 'Electricity'),
#  Text(0, 0, 'Diesel'),
#  Text(0, 0, 'Coal'),
#  Text(0, 0, 'LOT'),
#  Text(0, 0, 'CNG'),
#  Text(0, 0, 'Biomass'),
#  Text(0, 0, 'NG'),
#  Text(0, 0, 'Husk'),
#  Text(0, 0, 'Briquettes'),
#  Text(0, 0, 'Propane'),
#  Text(0, 0, 'Wood'),
#  Text(0, 0, 'LPG '),
#  Text(0, 0, 'Solar'),
#  Text(0, 0, 'HSD'),
#  Text(0, 0, 'PG'),
#  Text(0, 0, 'pet-coke'),
#  Text(0, 0, 'Power'),
#  Text(0, 0, 'Briquittes'),
#  Text(0, 0, 'Coal '),
#  Text(0, 0, 'Food Oil'),
#  Text(0, 0, 'MTO'),
#  Text(0, 0, 'Furnace Oil'),
#  Text(0, 0, 'Bio-waste'),
#  Text(0, 0, 'Direct Firing'),
#  Text(0, 0, 'Steam'),
#  Text(0, 0, 'Wind energy'),
#  Text(0, 0, 'Multi fuel'),
#  Text(0, 0, 'Captive power'),
#  Text(0, 0, 'LDO')]

# %%
chart = sns.countplot(x= "Fuel_Used", data= xl1.loc[xl1['Status'] == 'Prospect'])
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45, horizontalalignment = 'right')
# Out:
# [Text(0, 0, 'LPG'),
#  Text(0, 0, 'Diesel'),
#  Text(0, 0, 'Unknown'),
#  Text(0, 0, 'Propane'),
#  Text(0, 0, 'PG'),
#  Text(0, 0, 'Power'),
#  Text(0, 0, 'HSD'),
#  Text(0, 0, 'FO'),
#  Text(0, 0, 'Electricity')]

# %%
chart = sns.countplot(x= "Fuel_Used", data= xl1.loc[xl1['Status'] == 'Disqualified'])
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45, horizontalalignment = 'right')
# Out:
# [Text(0, 0, 'Unknown'),
#  Text(0, 0, 'FO'),
#  Text(0, 0, 'Electricity'),
#  Text(0, 0, 'LPG'),
#  Text(0, 0, 'Coal'),
#  Text(0, 0, 'Diesel'),
#  Text(0, 0, 'LOT'),
#  Text(0, 0, 'Husk'),
#  Text(0, 0, 'Briquettes'),
#  Text(0, 0, 'Wood'),
#  Text(0, 0, 'LPG '),
#  Text(0, 0, 'Solar'),
#  Text(0, 0, 'Briquittes'),
#  Text(0, 0, 'Coal '),
#  Text(0, 0, 'NG'),
#  Text(0, 0, 'Propane'),
#  Text(0, 0, 'Biomass'),
#  Text(0, 0, 'MTO'),
#  Text(0, 0, 'Furnace Oil'),
#  Text(0, 0, 'Direct Firing'),
#  Text(0, 0, 'Wind energy'),
#  Text(0, 0, 'LDO'),
#  Text(0, 0, 'HSD'),
#  Text(0, 0, 'pet-coke')]

# %%
chart = sns.countplot(x= "Industry", data= xl)
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45, horizontalalignment = 'right')
# Out:
# [Text(0, 0, 'Metal'),
#  Text(0, 0, 'Forging and Casting'),
#  Text(0, 0, 'Pharma'),
#  Text(0, 0, 'Rubber'),
#  Text(0, 0, 'Chemical'),
#  Text(0, 0, 'Food Processing'),
#  Text(0, 0, 'Automobile'),
#  Text(0, 0, 'Glass'),
#  Text(0, 0, 'Textiles'),
#  Text(0, 0, 'Cement'),
#  Text(0, 0, 'Plastic'),
#  Text(0, 0, 'Appliances'),
#  Text(0, 0, 'Other'),
#  Text(0, 0, 'Ceramics')]

# %%
chart = sns.countplot(x= "Industry", data= xl.loc[xl1['Status'] == 'Prospect'])
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45, horizontalalignment = 'right')
# Out:
# [Text(0, 0, 'Food Processing'),
#  Text(0, 0, 'Appliances'),
#  Text(0, 0, 'Pharma'),
#  Text(0, 0, 'Chemical'),
#  Text(0, 0, 'Rubber'),
#  Text(0, 0, 'Ceramics'),
#  Text(0, 0, 'Forging and Casting'),
#  Text(0, 0, 'Textiles'),
#  Text(0, 0, 'Automobile'),
#  Text(0, 0, 'Metal'),
#  Text(0, 0, 'Other'),
#  Text(0, 0, 'Glass')]

# %%
chart = sns.countplot(x= "Industry", data= xl.loc[xl1['Status'] == 'Disqualified'])
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45, horizontalalignment = 'right')
# Out:
# [Text(0, 0, 'Metal'),
#  Text(0, 0, 'Forging and Casting'),
#  Text(0, 0, 'Pharma'),
#  Text(0, 0, 'Rubber'),
#  Text(0, 0, 'Chemical'),
#  Text(0, 0, 'Food Processing'),
#  Text(0, 0, 'Automobile'),
#  Text(0, 0, 'Glass'),
#  Text(0, 0, 'Cement'),
#  Text(0, 0, 'Plastic'),
#  Text(0, 0, 'Appliances'),
#  Text(0, 0, 'Textiles'),
#  Text(0, 0, 'Ceramics'),
#  Text(0, 0, 'Other')]

# %%
#plt.figure(figsize = (15,15))
chart = sns.countplot(x= 'Industry', data = xl, hue = 'Status')
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45, horizontalalignment = 'right')
# Out:
# [Text(0, 0, 'Metal'),
#  Text(0, 0, 'Forging and Casting'),
#  Text(0, 0, 'Pharma'),
#  Text(0, 0, 'Rubber'),
#  Text(0, 0, 'Chemical'),
#  Text(0, 0, 'Food Processing'),
#  Text(0, 0, 'Automobile'),
#  Text(0, 0, 'Glass'),
#  Text(0, 0, 'Textiles'),
#  Text(0, 0, 'Cement'),
#  Text(0, 0, 'Plastic'),
#  Text(0, 0, 'Appliances'),
#  Text(0, 0, 'Other'),
#  Text(0, 0, 'Ceramics')]
